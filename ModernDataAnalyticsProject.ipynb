# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# !git clone https://github.com/27VG030/ModernDataAnalytics.git
# Out:
# fatal: destination path 'ModernDataAnalytics' already exists and is not an empty directory.

# %%
# Medical transport data

df_amb_loc = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/ambulance_locations.parquet.gzip?raw=true')
df_mug_loc = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/mug_locations.parquet.gzip?raw=true')
df_pit_loc = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/pit_locations.parquet.gzip?raw=true')

# Aed location data

df_aed_loc = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/aed_locations.parquet.gzip?raw=true')

# Interventions data

df_cad9 = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/cad9.parquet.gzip?raw=true')
df_bxl_int1 = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/interventions_bxl.parquet.gzip?raw=true')
df_bxl_int2 = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/interventions_bxl2.parquet.gzip?raw=true')
df_int1 = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/interventions1.parquet.gzip?raw=true')
df_int2 = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/interventions2.parquet.gzip?raw=true')
df_int3 = pd.read_parquet('https://github.com/27VG030/ModernDataAnalytics/blob/main/interventions3.parquet.gzip?raw=true')

# %%
print(df_amb_loc.head())  # Display the first few rows of the dataset
print(df_amb_loc.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_amb_loc.describe())  # Summary statistics for numerical columns
# Out:
#                                      base  \
# 0             BA ANTW [Borgerhout] AMBUCE
# 1                BA ANTW [Hoboken] AMBUCE
# 2  BA ANTW [Hof Ter Schelde] AC Antwerpen
# 3                BA ANTW [Kaai 606] SIHWA
# 4   BA ANTW [Sint Elisabeth] AC Antwerpen
#
#                                     medical_resource   province  \
# 0                   ZW ANTWERPEN 7 (Team: AAANTW07A)  Antwerpen
# 1                   ZW ANTWERPEN 9 (Team: AAANTW09A)  Antwerpen
# 2                   ZW ANTWERPEN 3 (Team: AAANTW03A)  Antwerpen
# 3  ZW ANTWERPEN HAVEN 1 (Team: AAAPOR01A)_x000D_Z...  Antwerpen
# 4                   ZW ANTWERPEN 2 (Team: AAANTW02A)  Antwerpen
#
#           region                         departure_location  \
# 0  Vlaams Gewest           Gijselstraat 150 2140 BORGERHOUT
# 1  Vlaams Gewest         Antwerpsesteenweg 242 2660 HOBOKEN
# 2  Vlaams Gewest      August Vermeylenlaan 6 2050 ANTWERPEN
# 3  Vlaams Gewest  Antwerpsebaan 4 (Kaai 606) 2040 ANTWERPEN
# ...

# %%
print(df_mug_loc.head())  # Display the first few rows of the dataset
print(df_mug_loc.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_mug_loc.describe())  # Summary statistics for numerical columns
# Out:
#    hospital_id  mug_id  campus_id                      name_hospital  \
# 0            9  102000       6230  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 1           99  102000       2020                  GZA- ZIEKENHUIZEN
# 2          682  102000       1210                          AZ MONICA
# 3            9  103000       2000  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 4           99  103000       1290                  GZA- ZIEKENHUIZEN
#
#         name_campus           address_campus  postal_code municipality region  \
# 0         ZNA CADIX         KEMPENSTRAAT 100         2030    ANTWERPEN      V
# 1   SINT-VINCENTIUS  ST.-VINCENTIUSSTRAAT 20         2018    ANTWERPEN      V
# 2            DEURNE     FLORENT PAUWELSLEI 1         2100       DEURNE      V
# 3    ZNA MIDDELHEIM            LINDENDREEF 1         2020    ANTWERPEN      V
# 4  SINT- AUGUSTINUS        OOSTERVELDLAAN 24         2610      WILRIJK      V
#
#     province
# 0  Antwerpen
# 1  Antwerpen
# 2  Antwerpen
# 3  Antwerpen
# ...

# %%
print(df_pit_loc.head())  # Display the first few rows of the dataset
print(df_pit_loc.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_pit_loc.describe())  # Summary statistics for numerical columns
# Out:
#                                  unit  \
# 0    100001: PIT Rumst, AZ Rivierland
# 1  102001: PIT Deinze, St Vincentius
# 2             102101: PIT Stuivenberg
# 3       110001: PIT Lier, Heilig Hart
# 4  113001: PIT HEILIG HART ZIEKENHUIS
#
#                                               campus  \
# 0  Ziekenhuis/Hôpital: 104 - AZ RIVIERENLAND --- ...
# 1  Ziekenhuis/Hôpital: 134 - AZ SINT-VINCENTIUS -...
# 2  Ziekenhuis/Hôpital: 009 - ZIEKENHUISNETWERK AN...
# 3  Ziekenhuis/Hôpital: 097 - HEILIG HART ZIEKENHU...
# 4  Ziekenhuis/Hôpital: 102 - HEILIG HART ZIEKENHU...
#
#                             province              region    unit_id  ambucode  \
# 0                   Antwerpen/Anvers  Vlaanderen/Flandre  PARUMS01A       191
# 1  Oost-Vlaanderen/Flandre orientale  Vlaanderen/Flandre  PODEIN01A       413
# 2                   Antwerpen/Anvers  Vlaanderen/Flandre  PAANTW01A       117
# 3                   Antwerpen/Anvers  Vlaanderen/Flandre  PALIER01A       171
# ...

# %%
print(df_aed_loc.head())  # Display the first few rows of the dataset
print(df_aed_loc.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_aed_loc.describe())  # Summary statistics for numerical columns
# Out:
#      id  type                address  number  postal_code municipality  \
# 0  13.0  None    Blvd. Fr. Roosevelt    24.0       7060.0     SOIGNIES
# 1  70.0  None        Ch. De Wégimont    76.0       4630.0      Ayeneux
# 2  71.0  None  Place Saint - Lambert     NaN       4020.0        Liège
# 3  72.0  None          Rue du Doyard     NaN       4990.0     Lierneux
# 4  73.0  None     Fond Saint Servais     NaN       4000.0        Liège
#
#   province location public available hours
# 0  Hainaut     None      Y      None  None
# 1    Liège     None   None      None  None
# 2    Liège     None   None      None  None
# 3    Liège     None   None      None  None
# 4    Liège     None   None      None  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15227 entries, 0 to 15226
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            15225 non-null  float64
# ...

# %%
print(df_cad9.head())  # Display the first few rows of the dataset
print(df_cad9.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_cad9.describe())  # Summary statistics for numerical columns
# Out:
#   province   Mission ID                 Service Name  Latitude permanence  \
# 0      VBR  21221520003             MV HVP VILV West            50.925277
# 1      VBR  21221520004             MV HVP HALL West            50.743200
# 2      VBR  21221520007             MV HVP VILV West            50.925277
# 3      VBR  21221520007   HV UR VILV AZ Jan Portaels            50.926869
# 4      VBR  21221520008  BB BRUX Hôpital Militair KA            50.905331
#
#    Longitude permanence Permanence short name Permanence long name  \
# 0              4.423057             AVVILV01A       ZW VILVOORDE 1
# 1              4.241053             AVHALL02A           ZW HALLE 2
# 2              4.423057             AVVILV01A       ZW VILVOORDE 1
# 3              4.420968             UVVILV01A        MUG VILVOORDE
# 4              4.387662             ABBRUX13A           AMB HMB 13
#
#   Vector Type                                  EventType Trip  \
# ...

# %%
print(df_bxl_int1.head())  # Display the first few rows of the dataset
print(df_bxl_int1.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_bxl_int1.describe())  # Summary statistics for numerical columns
# Out:
#     mission_id                   service_name  postalcode_permanence  \
# 0  20222490011  FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 1  20222490011  FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 2  20222490012       HB UR BRUX CHU St Pierre                   1000
# 3  20222490015  FB PDS BRUX [PASI CitÈ] SIAMU                   1000
# 4  20222490019   FB PDS WOLL [PASI UCL] SIAMU                   1200
#
#                            cityname_permanence  \
# 0                            Brussel (Brussel)
# 1                            Brussel (Brussel)
# 2                            Brussel (Brussel)
# 3                            Brussel (Brussel)
# 4  Woluwe-Saint-Lambert (Woluwe-Saint-Lambert)
#
#                  streetname_permanence housenumber_permanence  \
# 0                       Vesaliusstraat                   None
# 1                       Vesaliusstraat                   None
# 2                            Rue Haute                   None
# ...

# %%
print(df_bxl_int2.head())  # Display the first few rows of the dataset
print(df_bxl_int2.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_bxl_int2.describe())  # Summary statistics for numerical columns
# Out:
#     Mission ID                T0         Cityname Intervention  \
# 0  20221520003  01JUN22:00:02:45  1030 schaerbeek (schaerbeek)
# 1  20221520005  01JUN22:00:04:58  1030 schaerbeek (schaerbeek)
# 2  20221520006  01JUN22:00:07:43  1081 koekelberg (koekelberg)
# 3  20221520006  01JUN22:00:07:43  1081 koekelberg (koekelberg)
# 4  20221520007  01JUN22:00:09:18  1030 schaerbeek (schaerbeek)
#
#    Longitude intervention  Latitude intervention  description_nl  \
# 0            4.406731e+10           5.085516e+10  Nieuwe melding
# 1            4.368798e+10           5.086318e+10  Nieuwe melding
# 2            4.332312e+10           5.085755e+10  Nieuwe melding
# 3            4.332312e+10           5.085755e+10  Nieuwe melding
# 4            4.383695e+10           5.085225e+10  Nieuwe melding
#
#   ic_description_nl                           EventType and EventLevel  \
# 0           Medisch                                  P033 N05 - TRAUMA
# ...

# %%
print(df_int1.head())  # Display the first few rows of the dataset
print(df_int1.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_int1.describe())  # Summary statistics for numerical columns
# Out:
#     Mission ID                 Service Name  PostalCode permanence  \
# 0  10221520001     HA UR MECH AZ St Maarten                 2800.0
# 1  10221520002               BA KAPE AMBUCE                 2950.0
# 2  10221520002       HA UR ANTW Stuivenberg                 2060.0
# 3  10221520004  BA ANTW [Borgerhout] AMBUCE                 2140.0
# 4  10221520005               BA WIJN AMBUCE                 2110.0
#
#       CityName permanence   StreetName permanence HouseNumber permanence  \
# 0     Mechelen (Mechelen)          Liersesteenweg                   None
# 1     Kapellen (Kapellen)         Essenhoutstraat                   None
# 2   Antwerpen (Antwerpen)  Lange Beeldekensstraat                   None
# 3  Antwerpen (Borgerhout)           Gijselsstraat                   None
# 4     Wijnegem (Wijnegem)           Bijkhoevelaan                   None
#
#    Latitude permanence  Longitude permanence Permanence short name  \
# ...

# %%
print(df_int2.head())  # Display the first few rows of the dataset
print(df_int2.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_int2.describe())  # Summary statistics for numerical columns
# Out:
#     Mission ID                       Service Name  PostalCode permanence  \
# 0  50221920087       FH PDS COMI Wallonie Picarde                 7784.0
# 1  50221920088       FH PDS TOUR Wallonie Picarde                 7500.0
# 2  50221920089         FH PDS LOUV Hainaut Centre                 7100.0
# 3  50221920090  FW HVP HEUV [Nieuwkerke] Westhoek                 8950.0
# 4  50221920092                BH SGHI Croix Rouge                 7331.0
#
#            CityName permanence      StreetName permanence  \
# 0  Comines-Warneton (Warneton)          Chauss√©e d'Ypres
# 1            Tournai (Tournai)            Avenue de Maire
# 2  La Louvi√®re (La Louvi√®re)  Boulevard du Roi Baudouin
# 3      Heuvelland (Nieuwkerke)            Dranouterstraat
# 4     Saint-Ghislain (Baudour)             Rue Louis Caty
#
#   HouseNumber permanence  Latitude permanence  Longitude permanence  \
# 0                   None             50.76034              2.940230
# ...

# %%
print(df_int3.head())  # Display the first few rows of the dataset
print(df_int3.info())  # Get information about the dataset (data types, missing values, etc.)
print(df_int3.describe())  # Summary statistics for numerical columns
# Out:
#     Mission ID                        Service Name  PostalCode permanence  \
# 0  60230050009                 BG LIEG Croix Rouge                 4000.0
# 1  60230050010  FG PDS PEPI Vesdre Ho√´gne Plateau                 4860.0
# 2  60230050012                    BG LIEG Courtois                 4030.0
# 3  60230050013             FG PDS ANS_ Li√®ge IILE                 4000.0
# 4  60230050014             FG PDS FLEM Li√®ge IILE                 4400.0
#
#            CityName permanence  StreetName permanence HouseNumber permanence  \
# 0              Li√®ge (Li√®ge)            Rue Darchis                   None
# 1        Pepinster (Pepinster)         Rue Jean Simon                   None
# 2          Li√®ge (Grivegn√©e)            Rue Belvaux                   None
# 3               li√®ge (glain)  p537;rue jean jaur√®s                   None
# 4  Fl√©malle (Fl√©malle-Haute)            Grand'Route                   None
#
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# No duplicated values
df_amb_loc.duplicated().sum()
df_mug_loc.duplicated().sum()
df_pit_loc.duplicated().sum()
df_aed_loc.duplicated().sum() # 2 duplicates
df_cad9.duplicated().sum()
df_bxl_int1.duplicated().sum() # 2 duplicates
df_bxl_int2.duplicated().sum() # 1910 duplicates????
df_int1.duplicated().sum()
df_int2.duplicated().sum()
df_int3.duplicated().sum()
# Out:
# 0
# 0
# 0
# 2
# 0
# 2
# 1910
# 0
# 0
# 0

# %%
# Check for missing values
df_amb_loc.isnull().sum()
df_mug_loc.isnull().sum()
df_pit_loc.isnull().sum()
df_aed_loc.isnull().sum()
df_cad9.isnull().sum()
df_bxl_int1.isnull().sum()
df_bxl_int2.isnull().sum()
df_int1.isnull().sum()
df_int2.isnull().sum()
df_int3.isnull().sum()
# Out:
# base                          0
# medical_resource              0
# province                     13
# region                        0
# departure_location            0
# departure_location_number     0
# latitude                      0
# longitude                     0
# occasional_permanence         0
# dtype: int64
# hospital_id        0
# mug_id             0
# campus_id          0
# name_hospital      0
# name_campus       35
# address_campus     0
# postal_code        0
# municipality       0
# region             0
# province           0
# dtype: int64
# unit             0
# campus           0
# province         3
# region           0
# unit_id          0
# ambucode         0
# ambusitecode     0
# link            22
# dtype: int64
# id                  2
# type            10060
# address             2
# number           2142
# postal_code        34
# municipality       85
# province           37
# location         6804
# public           7148
# available       10937
# ...

# %%
# Visualize categorical columns
cat_columns = df_amb_loc.select_dtypes('object').columns
fig, axs = plt.subplots(len(cat_columns), 1, figsize=(10,20))


for i, column in enumerate(cat_columns):
    sns.countplot(x = column, data = df_amb_loc, ax=axs[i])
# Out:
# <Axes: xlabel='base', ylabel='count'>
# <Axes: xlabel='medical_resource', ylabel='count'>
# <Axes: xlabel='province', ylabel='count'>
# <Axes: xlabel='region', ylabel='count'>
# <Axes: xlabel='departure_location', ylabel='count'>
# <Axes: xlabel='occasional_permanence', ylabel='count'>

# %%
cat_columns = df_amb_loc.select_dtypes('object').columns
df_amb_loc[cat_columns].nunique()
# Out:
# base                     279
# medical_resource         279
# province                  10
# region                     3
# departure_location       279
# occasional_permanence      2
# dtype: int64

# %%
total = df_amb_loc.isnull().sum().sort_values(ascending=False)
percent = (df_amb_loc.isnull().sum()/df_amb_loc.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                            Total   Percent
# province                      13  0.046595
# base                           0  0.000000
# medical_resource               0  0.000000
# region                         0  0.000000
# departure_location             0  0.000000
# departure_location_number      0  0.000000
# latitude                       0  0.000000
# longitude                      0  0.000000
# occasional_permanence          0  0.000000

# %%
total = df_int2.isnull().sum().sort_values(ascending=False)
percent = (df_int2.isnull().sum()/df_int2.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                                    Total   Percent
# PostalCode destination hospital   200627  1.000000
# HouseNumber destination hospital  200627  1.000000
# PostalCode intervention           200627  1.000000
# T9                                196338  0.978622
# Unavailable time                  196094  0.977406
# HouseNumber permanence            193017  0.962069
# Abandon reason                    172263  0.858623
# T5                                 83359  0.415492
# Number of transported persons      81800  0.407722
# T4                                 76700  0.382301
# Calculated travelTime destinatio   72064  0.359194
# Calculated Distance destination    72064  0.359194
# T6                                 63411  0.316064
# T7                                 50516  0.251791
# StreetName destination hospital    49325  0.245854
# CityName destination hospital      49325  0.245854
# Name destination hospital          49325  0.245854
# ...
